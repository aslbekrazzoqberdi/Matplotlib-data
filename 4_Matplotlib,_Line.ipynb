# %% [markdown]
# <a href="https://colab.research.google.com/github/aslbekrazzoqberdi/Matplotlib-data/blob/main/4_Matplotlib%2C_Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
ypoints = np.array([10,50,30,75])

# %%
plt.plot(ypoints, ls = 'dotted')
plt.show()

# %%
x = np.array([15,45,25,65])

# %%
plt.plot(x, linewidth = '15.5', color = 'k')
plt.show()
